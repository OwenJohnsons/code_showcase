# %%
import pandas as pd
import numpy as np 
import math
import matplotlib.pyplot as plt 
import scipy.stats as stats
from scipy.optimize import curve_fit
# %matplotlib inline

# %%
plt.rcParams.update({'font.size': 22})
plt.rcParams["figure.figsize"] = (15,10)

# %% [markdown]
# ## Question 2

# %%
ire_pop = 50000
eng_pop = 500000

# %%
def breakdown(x): 
    print('Students within 1σ:', x*0.6827, 'Students within 2σ:', x*0.954, 'Students within 3σ:', x*0.997 )
    
breakdown(ire_pop)
breakdown(eng_pop)
# Out:
# Students within 1σ: 34135.0 Students within 2σ: 47700.0 Students within 3σ: 49850.0
# Students within 1σ: 341350.0 Students within 2σ: 477000.0 Students within 3σ: 498500.0

# %%
mu = 15
variance = 5
sigma = np.sqrt(variance)
x = np.linspace(mu - 3*sigma, mu + 3*sigma, 100)

plt.plot(x, stats.norm.pdf(x, mu, sigma))
plt.grid()

plt.show()

# %% [markdown]
# ## Question 3

# %%
def func(n_1, o_2, o_1): 
    return n_1*(np.sin(o_1)/np.sin(o_2))

# %%
a = math.sin(22.03)
b = math.sin(14.45)

print(b)
# Out:
# 0.9514655001553479

# %%
print(func(1, 22.03, 14.45))
# Out:
# -24.49601031968035

# %% [markdown]
# ## Question 4

# %%
d, h = np.loadtxt("volume.dat", unpack = True)

r = 0.5*d


print(np.mean(r), np.mean(h))

print(np.std(d), np.std(h))
# Out:
# 2.002 5.023999999999999
# 0.12472369462135098 0.1202663710269831

# %%
V_1 = np.pi*np.mean(h)*np.mean(r)**2

print(V_1)
# Out:
# 15.814943997979874

# %%
V_2 = np.pi*h*r**2

print(np.mean(V))
# Out:
# 15.881821518672746

# %%
def dh(r): 
    return np.pi*r**2

def dr(r, h): 
    return 2*np.pi*r*h

# %%
σ_1 = 0.01
σ_2 = 0.01 

σ = np.sqrt(σ_1**2*(dh(r))**2 + σ_2**2*(dr(r, h))**2)

print(np.mean(σ))
# Out:
# 0.31761954858776686
